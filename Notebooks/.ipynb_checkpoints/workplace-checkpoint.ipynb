# %%
import pandas as pd

# %%
df_connect = pd.read_csv('/home/giovane/hackathon_24/ClubStay/data/fa_connect.csv')
df_socio = pd.read_csv('/home/giovane/hackathon_24/ClubStay/data/socio_torcedor.csv')
df_wifi = pd.read_csv('/home/giovane/hackathon_24/ClubStay/data/wifi.csv')

# %%
df_connect.head()
# Out:
#    _id  numero_de_camisa_preferido  tamanho_do_sapato  quantidade_de_filhos  \
# 0    1                          10                 42                     2
# 1    2                           7                 39                     0
# 2    3                          23                 44                     3
# 3    4                          11                 41                     1
# 4    5                           8                 43                     4
#
#    altura  peso cidade_de_nascimento        renda comida_favorita  \
# 0     175    70            sao_paulo  2501 a 5000       churrasco
# 1     160    55       rio_de_janeiro  1501 a 2500           pizza
# 2     182    85       belo_horizonte     0 a 1500           sushi
# 3     168    65             salvador     0 a 1500           massa
# 4     190    90         porto_alegre     0 a 1500      hamburguer
#
#   bebida_favorita look_que_mais_combina videogame_favorito  \
# ...

# %%
df_connect.columns
# Out:
# Index(['_id', 'numero_de_camisa_preferido', 'tamanho_do_sapato',
#        'quantidade_de_filhos', 'altura', 'peso', 'cidade_de_nascimento',
#        'renda', 'comida_favorita', 'bebida_favorita', 'look_que_mais_combina',
#        'videogame_favorito', 'tempo_de_associacao_torcedor_m',
#        'modalidade_esportiva_interesse', 'interesse_em_merchandising',
#        'canal_de_comunicacao_preferido'],
#       dtype='object')

# %%
df_wifi.shape , df_connect.shape , df_socio.shape
# Out:
# ((4999, 16), (4999, 16), (4999, 13))

# %%
df_socio.head()
# Out:
#    _id  tempo_de_assinatura  historico_de_presenca_nos_jogos  \
# 0    1                   39                               71
# 1    2                   52                               60
# 2    3                   29                               20
# 3    4                   15                               82
# 4    5                   43                               86
#
#    historico_de_socio  numero_de_desistencias_no_periodo  \
# 0                  11                                  4
# 1                   1                                  1
# 2                   4                                  3
# 3                   8                                  1
# 4                   3                                  3
#
#    historico_de_preco_nos_planos tipo_de_plano  quantos_membros  \
# 0                            134      familiar                4
# 1                            219      familiar                3
# ...

# %% [markdown]
# df_socio['estado_civil'].unique()

# %%
df_socio.columns
# Out:
# Index(['_id', 'tempo_de_assinatura', 'historico_de_presenca_nos_jogos',
#        'historico_de_socio', 'numero_de_desistencias_no_periodo',
#        'historico_de_preco_nos_planos', 'tipo_de_plano', 'quantos_membros',
#        'planos_com_ingresso_incluso', 'estado_civil', 'risco_de_churn',
#        'feedback_sobre_servicos', 'frequencia_de_compra_de_produtos'],
#       dtype='object')

# %%
df_wifi.head()
# Out:
#   ticket_medio_do_usuario renda_familiar  historico_no_estadio       spc  \
# 0                  494,33    2501 a 5000                    16  Positivo
# 1                  406,34       0 a 1500                    17  Negativo
# 2                  178,93       0 a 1500                     7  Negativo
# 3                  182,40    1501 a 2500                    12  Positivo
# 4                  331,29    1501 a 2500                    11  Negativo
#
#     profissao   composicao_familiar socio_torcedor assinante_do_premiere  \
# 0   Professor           Solteiro(a)            Não                   Não
# 1  Engenheiro  Casado(a) com filhos            Sim                   Sim
# 2    Advogado  Casado(a) sem filhos            Não                   Sim
# 3  Engenheiro           Solteiro(a)            Não                   Não
# 4   Professor         Divorciado(a)            Sim                   Sim
#
#   comida_favorita bebida_favorita produtos_potenciais  \
# ...

# %%
df_wifi.columns
# Out:
# Index(['ticket_medio_do_usuario', 'renda_familiar', 'historico_no_estadio',
#        'spc', 'profissao', 'composicao_familiar', 'socio_torcedor',
#        'assinante_do_premiere', 'comida_favorita', 'bebida_favorita',
#        'produtos_potenciais', 'numero_de_acessos_na_web',
#        'retencao_pagina_segundos', 'emails_recebidos', 'sms_recebidos',
#        'n_transacoes'],
#       dtype='object')
